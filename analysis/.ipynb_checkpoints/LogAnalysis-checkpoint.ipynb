# %%
#Setup and read in log file
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.options.display.float_format = '{:.2f}'.format

sns.set(style="darkgrid")

df = pd.read_csv('choucas_experience.tsv', sep='\t')
df['time']= df['time'] / 1000 #convert ms to seconds

dfTut = df[df['logSection'] == 'Tutorial']
dfExp = df[df['logSection'] == 'Experiment']

#Choose whether we want to run analysis on the tutorial or the experiment
df = dfExp
df = dfTut
df
# Out:
#    logSection   time                                            logText  \
# 7    Tutorial   0.00                      ----- Starting Tutorial -----
# 8    Tutorial   0.00                                Initialising System
# 9    Tutorial   0.00                               Loading base map OSM
# 10   Tutorial   0.03                       Adding a new filter: Filter1
# 11   Tutorial   0.19                                 loadInitialItems()
# 12   Tutorial   0.19                                 runOverpassQuery()
# 13   Tutorial   0.19  Overpass Query: https://overpass-api.de/api/in...
# 14   Tutorial   0.19              Initialisation completed successfully
# 15   Tutorial   0.19                   ExperimentInstructions Step 1/12
# 16   Tutorial   4.11               Overpass query response received in:
# 17   Tutorial   4.29                Finished Processing items in: 0.18s
# 18   Tutorial   5.96                                         userName:
# 19   Tutorial   5.96                   ExperimentInstructions Step 2/12
# 20   Tutorial   6.34               Overpass query response received in:
# 21   Tutorial   6.44               Finished Processing items in: 0.099s
# 22   Tutorial   6.64                   ExperimentInstructions Step 3/12
# 23   Tutorial  11.17                 Node selected: Croix de Chamrousse
# 24   Tutorial  11.25                                 Current Zone Size:
# 25   Tutorial  11.38  treeNodeHoverStart() 26864747, Croix de Belled...
# 26   Tutorial  13.46                         bufferChanged() Filter1, 3
# 27   Tutorial  13.63                                 Current Zone Size:
# 28   Tutorial  14.63                         bufferChanged() Filter1, 3
# 29   Tutorial  14.74                                 Current Zone Size:
# 30   Tutorial  14.78               checkboxChanged() Filter1, scenario1
# 31   Tutorial  14.83                                 Current Zone Size:
# 32   Tutorial  16.07                              fitMapToCurrentZone()
# 33   Tutorial  18.42                         loadMapItemsFromOverpass()
# 34   Tutorial  18.42                      Zoom Level: 13.79169300082762
# 35   Tutorial  18.42                                 runOverpassQuery()
# 36   Tutorial  18.42  Overpass Query: https://overpass-api.de/api/in...
# ..        ...    ...                                                ...
# 57   Tutorial 194.29                                 Current Zone Size:
# 58   Tutorial 198.32                                Node selected: Lacs
# 59   Tutorial 198.42                                 Current Zone Size:
# 60   Tutorial 198.63         treeNodeHoverStart() undefined, Randonnées
# 61   Tutorial 199.61                          Node selected: Réservoirs
# 62   Tutorial 199.72                                 Current Zone Size:
# 63   Tutorial 199.75         treeNodeHoverStart() undefined, Plan d'Eau
# 64   Tutorial 200.98                       bufferChanged() Filter2, 0.1
# 65   Tutorial 201.46                                 Current Zone Size:
# 66   Tutorial 201.86                     distanceChanged() Filter2, 0.1
# 67   Tutorial 202.29                                 Current Zone Size:
# 68   Tutorial 202.33                     distanceChanged() Filter2, 0.2
# 69   Tutorial 202.54                                 Current Zone Size:
# 70   Tutorial 203.56               checkboxChanged() Filter2, scenario1
# 71   Tutorial 203.69                                 Current Zone Size:
# 72   Tutorial 204.86                       Adding a new filter: Filter3
# 73   Tutorial 205.06                                 Current Zone Size:
# 74   Tutorial 208.91                Node selected: Remontées mécaniques
# 75   Tutorial 209.04                                 Current Zone Size:
# 76   Tutorial 210.08         treeNodeHoverStart() undefined, Randonnées
# 77   Tutorial 211.20                       bufferChanged() Filter3, 0.1
# 78   Tutorial 211.38                                 Current Zone Size:
# 79   Tutorial 212.59               checkboxChanged() Filter3, scenario1
# 80   Tutorial 212.73                                 Current Zone Size:
# 81   Tutorial 218.88                   ExperimentInstructions Step 4/12
# 82   Tutorial 219.42                   ExperimentInstructions Step 5/12
# 83   Tutorial 219.86                   ExperimentInstructions Step 6/12
# 84   Tutorial 220.28                   ExperimentInstructions Step 7/12
# 85   Tutorial 220.70                   ExperimentInstructions Step 8/12
# 86   Tutorial 221.30                   ExperimentInstructions Step 9/12
#
#          value
# 7          nan
# 8          nan
# 9          nan
# 10         nan
# 11         nan
# 12         nan
# 13         nan
# 14         nan
# 15         nan
# 16     5106.00
# 17         nan
# 18         nan
# 19         nan
# 20     6147.00
# 21         nan
# 22         nan
# 23         nan
# 24         nan
# 25         nan
# 26         nan
# 27         nan
# 28         nan
# 29         nan
# 30         nan
# 31 13984797.53
# 32         nan
# 33         nan
# 34         nan
# 35         nan
# 36         nan
# ..         ...
# 57 13984797.53
# 58         nan
# 59 13984797.53
# 60         nan
# 61         nan
# 62 13984797.53
# 63         nan
# 64         nan
# 65 13984797.53
# 66         nan
# 67 13984797.53
# 68         nan
# 69 13984797.53
# 70         nan
# 71  1104579.93
# 72         nan
# 73  1104579.93
# 74         nan
# 75  1104579.93
# 76         nan
# 77         nan
# 78  1104579.93
# 79         nan
# 80   122918.81
# 81         nan
# 82         nan
# 83         nan
# 84         nan
# 85         nan
# 86         nan
#
# [80 rows x 4 columns]

# %%
#Stats Table
dfStats = pd.DataFrame(columns=['Statistic','Value'])

#Overpass Query Statistics
dfStats.loc[len(dfStats.index)+1] = ['Count runOverpassQuery', df.logText.str.count("runOverpassQuery").sum()]
meanOverpassQuery = df[df['logText'] == 'Overpass query response received in:'].value.mean() / 1000
dfStats.loc[len(dfStats.index)+1] = ['Avg Overpass Query Time (s)', meanOverpassQuery]
maxOverpassQuery = df[df['logText'] == 'Overpass query response received in:'].value.max() / 1000
dfStats.loc[len(dfStats.index)+1] = ['Max Overpass Query Time (s)', maxOverpassQuery]

#Filter Table Stats
dfStats.loc[len(dfStats.index)+1] = ['Count Adding a new filter', df.logText.str.count("Adding a new filter").sum()]
dfStats.loc[len(dfStats.index)+1] = ['Count bufferChanged', df.logText.str.count("bufferChanged").sum()]
dfStats.loc[len(dfStats.index)+1] = ['Count distanceChanged', df.logText.str.count("distanceChanged").sum()]
dfStats.loc[len(dfStats.index)+1] = ['Count checkboxChanged', df.logText.str.count("checkboxChanged").sum()]

#ZoneCalcStats
dfStats.loc[len(dfStats.index)+1] = ['Count zoneCalculations', df.logText.str.count("Current Zone Size").sum()]

dfStats
# Out:
#                      Statistic Value
# 1       Count runOverpassQuery     3
# 2  Avg Overpass Query Time (s)  7.43
# 3  Max Overpass Query Time (s) 11.05
# 4    Count Adding a new filter     3
# 5          Count bufferChanged     4
# 6        Count distanceChanged     2
# 7        Count checkboxChanged     3
# 8       Count zoneCalculations    15

# %%
#Zone size over time graph
dfZoneSize = df[df['logText'] == 'Current Zone Size:']
plt.ticklabel_format(useOffset=False, style='plain')
plt.title('Size of the most likely zone over time')
plt.xlabel('Time Elapsed (s)')
plt.ylabel('Zone Size')
plt.plot(dfZoneSize['time'], dfZoneSize['value']);
